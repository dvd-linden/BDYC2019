# %% [markdown]
# <font face="papyrus">
# <p style="text-align:center;"><font size="6"><b>Big Data Engineer Eindopdracht</b></font></p>
# <p style="text-align:center;"><font size="6"><b>Peter Kremers en Dennis van der Linden</b></font></p>
# <hr noshade size="2px" width="100%">
# </br>
# <p style="text-align:center;"><font size="5"><b><u>Plan van aanpak</u></b></font></p>
# </br>
# <ul>
#     <li><font size="4"><b>Bepaling van het onderwerp (work-in progress):</b></font></li>
#         <ul>
#             <li><font size="3">Er zijn 3 hoofdonderwerpen door ons opgesteld. Bij elk onderwerp hebben we een probleemstelling/onderzoeksvraag geformuleerd</font></li>
#             <li><font size="3">Het defintieve onderwerp is door ons nog niet gekozen; dit zal gebeuren na het zoeken naar datasets</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Het zoeken van datasets (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Het zoeken datasets die geschikt zijn voor onze probleemstelling/onderzoeksvraag</font></li>
#             <li><font size="3">Het verkrijgen van de datasets</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Toetsing van de datasets --> op inhoud, technische aspecten en geschiktheid voor bewerking (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Zijn de datasets die we hebben gevonden dusdanig van aard dat ze informatie bevatten die benodigd is voor het oplossen van onze probleemstelling/onderzoeksvraag?</font></li>
#             <li><font size="3">Zijn de gevonden datasets geschikt voor extract, transform, load waardoor deze ook bruikbaar zijn voor ons onderzoek?
#         - Bestandstype waar we mee kunnen werken? (API/JSON, CSV, XML)</font></li>
#             <li><font size="3">Is er metadata beschikbaar over deze datasets (veracity)?</font></li>
#             <li><font size="3">Kunnen de gevonden datasets gecombineerd worden?</font></li>
#             <li><font size="3">Wat voor soort data hebben we nou eigenlijk?</font></li>
#             <ul>
#                  <li><font size="3">Realtime vs. batch?</font></li>
#                  <li><font size="3">Gestructureerd, semi-gestructureerd of ongestructureerd?</font></li>
#             </ul>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Wat zijn de benodigde applicaties/middelen voor de uitvoering van het project? (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Python/Jupyter Notebooks (pandas, numpy, matplotlib, etc.)</font></li>
#             <li><font size="3">SQL?</font></li>
#             <li><font size="3">PowerBI?</font></li>
#             <li><font size="3">Github</font></li>
#             <li><font size="3">Azure?</font></li>
#             <li><font size="3">Excel?</font></li>
#             <li><font size="3" color="red">Powerpoint.... NEE</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Enkele visualisaties om een globaal beeld te krijgen (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Python describe</font></li>
#             <li><font size="3">Enkele plots (bv. scatter)</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Data cleaning (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Onderzoeken op missing values (NaN)</font></li>
#             <ul>
#                <li><font size="3">In het geval deze voor komen dan beslissen of het nodig is om deze te verwijderen of niet</font></li>
#                <li><font size="3">Sentinels opsporen en er actie op ondernemen</font></li>
#                <li><font size="3">Checken of masking nodig is</font></li>
#             </ul>
#             <li><font size="3">Onderzoeken op verschillende soorten datatypes</font></li>
#             <ul>
#               <li><font size="3">Welke datatypes zijn bruikbaar? (welke datatypes hebben we nodig)</font></li>
#               <li><font size="3">Datatypes converteren?</font></li>
#             </ul>
#             <li><font size="3">Onderzoek doen naar betekenis van verschillende variabelen</font></li>
#             <ul>
#              <li><font size="3">Bepalen welke variabelen betekenis hebben en we op willen nemen in onze analyse</font></li>
#             </ul>
#             <li><font size="3">Dataframe creëren met daarin alleen de voor ons bruikbare variabelen</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Data analyse/visualisatie (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Onderzoek doen naar verbanden die relevant zijn en een verklarend vermogen hebben met betrekking tot probleemstelling/onderzoeksvraag</font></li>
#             <ul>
#                 <li><font size="3">Correlatie</font></li>
#                 <li><font size="3">Regressie (linear, multiple linear, logistic)</font></li>
#                 <li><font size="3">Eventuele classificatie of clustering methodes?</font></li>
#                 <li><font size="3">Heat maps/spacial data analysis?</font></li>
#             </ul>
#             <li><font size="3">Hebben we genoeg data verzameld?</font></li>
#             <ul>
#                 <li><font size="3">Stel dat er geen enkel resultaat uit de analyse komt, dan moeten we de vraag stellen of we de juiste (hoeveelheid) data hebben verzameld en of we het data cleaning proces wel correct hebben uitgevoerd.</font></li>
#             </ul>
#             <li><font size="3">Iteratief proces</font></li>
#             <ul>
#                 <li><font size="3">Mocht het nodig zijn dat er meer data verzameld moet worden of dat de cleaning stage opnieuw moet dan moet er ook een nieuwe analyse uitgevoerd worden.</font></li>
#             </ul>
#             <li><font size="3">Uiteindelijke visualisaties opstellen die opgenomen kunnen worden in de presentatie</font></li>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Interpretatie van resultaten en conclusies trekken (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Wordt de probleemstelling/onderzoeksvraag beantwoord?</font></li>
#             <li><font size="3">Zijn er mogelijke bezwaren die het resultaat of de conclusies kunnen weerleggen?</font></li>
#             <li><font size="3">Zijn er beperkingen aan het resultaat of de conclusie?</font></li>
#             <li><font size="3">Zijn er, aan de hand van het onderzoek, andere invalshoeken aan het licht gekomen die zouden kunnen wijzen op verder onderzoek of een herhaling van het onderzoek?</font></li>
#             <li><font size="3">Kunnen de resultaten gebruikt worden door een organisatie/bedrijf en/of de overheid? (utilization of analysis results)</font></li>
#             <ul>
#                <li><font size="3">Kan er een model opgesteld worden</font></li>
#             </ul>
#         </ul>
# </ul>
# </br>
# <ul>
#     <li><font size="4"><b>Het verloop van het project + de resultaten van het project uitwerken in een presentatie (to-do):</b></font></li>
#         <ul>
#             <li><font size="3">Notebook opstellen met voor de presentatie</font></li>
#             <ul>
#                <li><font size="3">De uiteindelijke resultaten en bijbehorende visualisaties</font></li>
#                <li><font size="3">Beschrijving van het proces</font></li>
#                <li><font size="3">Problemen waar we tegenaan gelopen zijn (deze ophalen uit het notebook met daarin de problemen)   </font></li>
#             </ul>
#             <li><font size="3">Bepaling wie wat presenteert</font></li>
#             <li><font size="3">Presentatie uitschrijven en voorbereiden/oefenen</font></li>
#         </ul>
# </ul>
# </br>
# <hr noshade size="2px" width="100%">
# <p style="text-align:right;"><font size="3">© Peter Kremers en Dennis van der Linden</font></p>
# </font>
